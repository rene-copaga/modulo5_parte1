# %%
import numpy
import pandas as pd
from pyspc import *

# %%
data = pd.read_csv('winequality-red.csv')
quality = data['quality']
quality
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
# 5       5
# 6       5
# 7       7
# 8       7
# 9       5
# 10      5
# 11      5
# 12      5
# 13      5
# 14      5
# 15      5
# 16      7
# 17      5
# 18      4
# 19      6
# 20      6
# 21      5
# 22      5
# 23      5
# 24      6
# 25      5
# 26      5
# 27      5
# 28      5
# 29      6
#        ..
# 1569    6
# 1570    6
# 1571    6
# 1572    5
# 1573    6
# 1574    6
# 1575    6
# 1576    6
# 1577    6
# 1578    6
# 1579    5
# 1580    6
# 1581    5
# 1582    5
# 1583    5
# 1584    7
# 1585    6
# 1586    6
# 1587    6
# 1588    6
# 1589    5
# 1590    6
# 1591    6
# 1592    6
# 1593    6
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
a = spc(quality) + ewma()
print(a)
# Out:
# <pyspc: (-9223371872637316541)>
